# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# %%
# Load the dataset
data = pd.read_csv("C:/Users/Administrator/Desktop/DL/letter-recognition (1).csv")

# %%
# Check the column names
print("Column Names:", data.columns)
# Out:
# Column Names: Index(['T', '2', '8', '3', '5', '1', '8.1', '13', '0', '6', '6.1', '10', '8.2',
#        '0.1', '8.3', '0.2', '8.4'],
#       dtype='object')

# %%
# Preprocess the data
X = data.drop(columns=['T'])  # Features
y = data['T']  # Target

# %%
# Encode target labels
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)

# %%
# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y_encoded, test_size=0.2, random_state=42)

# %%
# Build the model
model = Sequential([
    Dense(128, activation='relu', input_shape=(X_train.shape[1],)),
    Dense(64, activation='relu'),
    Dense(len(label_encoder.classes_), activation='softmax')  # Output layer with number of classes
])

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model
model.fit(X_train, y_train, epochs=20, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/20
# 400/400 [==============================] - 2s 3ms/step - loss: 1.8316 - accuracy: 0.4854 - val_loss: 1.1848 - val_accuracy: 0.6775
# Epoch 2/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.9905 - accuracy: 0.7191 - val_loss: 0.9183 - val_accuracy: 0.7303
# Epoch 3/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.7880 - accuracy: 0.7774 - val_loss: 0.7624 - val_accuracy: 0.7703
# Epoch 4/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.6653 - accuracy: 0.8050 - val_loss: 0.6404 - val_accuracy: 0.8122
# Epoch 5/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.5886 - accuracy: 0.8280 - val_loss: 0.5540 - val_accuracy: 0.8356
# Epoch 6/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.5161 - accuracy: 0.8473 - val_loss: 0.5166 - val_accuracy: 0.8431
# Epoch 7/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.4713 - accuracy: 0.8583 - val_loss: 0.4919 - val_accuracy: 0.8409
# Epoch 8/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.4329 - accuracy: 0.8658 - val_loss: 0.4408 - val_accuracy: 0.8612
# Epoch 9/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3983 - accuracy: 0.8771 - val_loss: 0.4166 - val_accuracy: 0.8731
# Epoch 10/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3677 - accuracy: 0.8877 - val_loss: 0.3929 - val_accuracy: 0.8750
# Epoch 11/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3526 - accuracy: 0.8917 - val_loss: 0.4099 - val_accuracy: 0.8697
# Epoch 12/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3326 - accuracy: 0.8966 - val_loss: 0.3598 - val_accuracy: 0.8872
# Epoch 13/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.3089 - accuracy: 0.9036 - val_loss: 0.3328 - val_accuracy: 0.8953
# Epoch 14/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.2923 - accuracy: 0.9102 - val_loss: 0.3448 - val_accuracy: 0.8841
# Epoch 15/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.2769 - accuracy: 0.9143 - val_loss: 0.3754 - val_accuracy: 0.8756
# Epoch 16/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.2669 - accuracy: 0.9167 - val_loss: 0.3262 - val_accuracy: 0.8888
# Epoch 17/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.2579 - accuracy: 0.9180 - val_loss: 0.2790 - val_accuracy: 0.9119
# Epoch 18/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.2449 - accuracy: 0.9219 - val_loss: 0.2862 - val_accuracy: 0.9119
# Epoch 19/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.2312 - accuracy: 0.9262 - val_loss: 0.2813 - val_accuracy: 0.9078
# Epoch 20/20
# 400/400 [==============================] - 1s 2ms/step - loss: 0.2325 - accuracy: 0.9269 - val_loss: 0.2907 - val_accuracy: 0.9056

# %%
# Evaluate the model
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# 125/125 [==============================] - 0s 2ms/step - loss: 0.3007 - accuracy: 0.9050
# Test Accuracy: 0.9049999713897705

# %%
# Make predictions
predictions = model.predict(X_test)
# Out:
# 125/125 [==============================] - 0s 1ms/step

# %%
# Decode the predicted labels
predicted_labels = label_encoder.inverse_transform(np.argmax(predictions, axis=1))

# %%
# Decode the actual labels
actual_labels = label_encoder.inverse_transform(y_test)

# %%
# Print some predicted and actual results
print("Some Predicted and Actual Results:")
for i in range(10):
    print("Predicted:", predicted_labels[i], "Actual:", actual_labels[i])
# Out:
# Some Predicted and Actual Results:
# Predicted: X Actual: X
# Predicted: R Actual: R
# Predicted: P Actual: P
# Predicted: I Actual: I
# Predicted: I Actual: I
# Predicted: A Actual: Z
# Predicted: C Actual: C
# Predicted: Y Actual: Y
# Predicted: G Actual: G
# Predicted: X Actual: X
